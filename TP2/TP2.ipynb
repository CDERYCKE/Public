# %% [markdown]
# # Traitement d'images numériques
#
# Utilisation de pillow en python pour traiter des images
#
# But : programmer en Python quelques modifications d'image simples

# %% [markdown]
# <div class="alert alert-info" role="alert">
#   <strong>Travail à faire sur le notebook : </strong> <br>
#     Pour les cellules suivantes, appuyez sur <strong>shift + entrée </strong>pour lancer le code Python contenu chaque cellule
# </div>

# %%
from PIL.Image import * # permet d'importer le module image de la bibliothèque PIL

# %% [markdown]
# # 1. Réalisation d'un filtre rouge :
# Rappels :
# Les composantes de couleur d'un pixel sont données par trois nombres r,v,b <br>
# qui sont des entiers compris entre 0 et 255 et qui indiquent la proportion de lumière rouge, verte ou bleue.
#
# En combinant ces 3 composantes on peut refabriquer l'ensemble des couleurs.
#
# On souhaite réaliser un filtre rouge qui conserve la composante rouge de chaque pixel mais qui passe les autres composantes à la valeur zéro.

# %% [markdown]
# On commence par ouvrir l'image en mémoire et récupérer ses dimensions

# %%
img=open("colors.jpg") #crée un objet img qui contient l'image colors.jpg
largeur = img.width
hauteur = img.height
print ('largeur : ', largeur, 'pixels', '; hauteur : ', hauteur,'pixels')
img

# %% [markdown]
# ___
# On va utiliser une double boucle pour parcourir et modifier les pixels un par un.

# %% [markdown]
# <div class="alert alert-info" role="alert">
#   <strong>Travail à faire sur le notebook : </strong> <br>
#     Pour la cellule suivante, appuyez sur <strong>shift + entrée </strong>pour lancer le code Python contenu chaque cellule,<br>
#     ...<br>
#     Attendre la fin du traitement et l'affichage de l'image
# </div>

# %%
img=open("colors.jpg") #recrée un objet img qui contient l'image colors.jpg si celui-ci a été modifié avant
for x in range(0,largeur):
    for y in range(0,hauteur):
        # Ici on traite le pixel (x,y) de l'image
        (R_pixel,V_pixel,B_pixel)=img.getpixel((x,y)) # on récupère sa couleur sous forme d'un triplet (R_pixel,V_pixel,B_pixel)
        img.putpixel((x,y), (0,V_pixel,0)) # on remplace ce pixel par un pixel de couleur à la même place 
img # pour afficher l'image dans le notebook

# %% [markdown]
# <div class="alert alert-warning" role="alert">
#     <strong> Travail à faire sur la fiche réponse : </strong> <br>
#     --> Répondre aux questions<br>
#     --> Recopier les lignes de code qui permettent d'obtenir un filtre rouge<br>
#     --> compléter le schéma de modification des couleurs
# </div>

# %% [markdown]
# # 2. Permuter les couleurs

# %% [markdown]
# On souhaite réaliser une permutation des couleurs : le rouge devient vert, le vert devient bleu et le bleu devient rouge.

# %% [markdown]
# <div class="alert alert-warning" role="alert">
#     <strong> Travail à faire sur la fiche réponse : </strong> <br>
#     --> demander au professeur la permutation à réaliser <br>
#     --> compléter le schéma de modification des couleurs <br>
# </div>

# %% [markdown]
# <div class="alert alert-info" role="alert">
#   <strong>Travail à faire sur le notebook : </strong> <br>
#    --> Modifier le code ci-dessous pour qu'il accomplisse la permutation souhaitée<br>
#    --> Faire vérifier<br>
#
# </div>

# %%
img=open("colors.jpg") #recrée un objet img qui contient l'image colors.jpg si celui-ci a été modifié avant
for x in range(0,largeur):
    for y in range(0,hauteur):
        # Ici on traite le pixel (x,y) de l'image
        (R_pixel,V_pixel,B_pixel)=img.getpixel((x,y))
        img.putpixel((x,y), ( 0,V_pixel,0))
img # pour afficher l'image dans le notebook

# %% [markdown]
# <div class="alert alert-warning" role="alert">
#     <strong> Travail à faire sur la fiche réponse : </strong> <br>
#     --> recopier le code <br>
# </div>

# %% [markdown]
# # 3. Passage d'une image couleur en son négatif
#
# Le principe du filtre négatif est de remplacer chaque composante par son complémentaire :
#
# 0 devient 255 soit 255-0
#
# 255 devient 0 soit 255-255
#
# une valeur x est remplacée par son complémentaire soit 255-x
#
# **exemples :**
# le bleu primaire (0,0,255) est remplacé par le jaune (255,255,0)
#
# un jaune peu intense (x,x,0) est remplacé par un bleu (255-x,255-x,255-0=255)
#
# le blanc (255,255,255) est remplacé par le noir (0,0,0) et réciproquement
#
# à votre avis par quoi sera remplacé le pixel dont la couleur est (0,0, b) ?

# %% [markdown]
# <div class="alert alert-info" role="alert">
#   <strong>Travail à faire sur le notebook : </strong> <br>
#     Pour la cellule suivante, appuyez sur <strong>shift + entrée </strong>pour lancer le code Python et afficher l'image de départ
# </div>

# %%
img=open("eowyn.jpg") #recrée un objet img qui contient l'image initiale eowyn.jpg
img

# %% [markdown]
# <div class="alert alert-warning" role="alert">
#     <strong> Travail à faire  : </strong> <br>
#     --> sur la fiche réponse : compléter le schéma et répondre aux questions<br>
#     --> sur le notebook , modifier le code de manière à obtenir le négatif<br>
#     --> sur la fiche réponse : recopier le code Python permettant de créer un négatif
# </div>

# %%
img=open("eowyn.jpg") #recrée un objet img qui contient l'image initiale eowyn.jpg
largeur, hauteur = img.size # met les valeurs de largeur et de hauteur pour ce nouvel objet
for x in range(0,largeur):
    for y in range(0,hauteur):
        # Ici on traite le pixel (x,y) de l'image
        (R_pixel,V_pixel,B_pixel)=img.getpixel((x,y))
        img.putpixel((x,y), ( 0 , 0 , 0 ))

img.save("eowyn_neg.jpg")
img # pour afficher l'image dans le notebook

# %% [markdown]
# ___

# %% [markdown]
# <div class="alert alert-success" role="alert">
#  <strong> 2 possibilités pour la suite du travail </strong> <br>
# </div>

# %% [markdown]
# # 3. Modification de l'intensité de la couleur (niveau facile)

# %% [markdown]
# On dispose d’une image de paysage, les couleurs sont un peu passées sauf le bleu qui semble « trop bleu ».

# %%
img=open("paysage.jpg")
img

# %% [markdown]
# Pour intensifier le rouge, on va multiplier par 1.2 la valeur de rouge du pixel étudié...
# et il faut aussi transformer le résultat en nombre entier sinon l’instruction img.putpixel((x,y), ( , , )) ne va pas fonctionner .
#
# On utilise int() devant le calcul : int(R_pixel*1.2) donnera ainsi une valeur en nombre entier
# <b>( attention à l'écriture 1.2 et non 1,2 !) <b>
#
# Cependant pour le bleu, on va diminuer l’intensité du bleu pour le pixel étudié :
# on va multiplier la valeur de bleu du pixel étudié par un nombre plus petit que 1 (à tester).

# %% [markdown]
# <div class="alert alert-warning" role="alert">
#     <strong> Travail à faire  : </strong> <br>
#     --> sur le notebook , compléter le code de manière à obtenir la transformation demandée<br>
#     --> sur la fiche réponse : recopier le code Python permettant d'obtenir une photo de meilleure qualité visuelle<br>
# </div>

# %%
img=open("paysage.jpg") #crée un objet img qui contient l'image initiale

largeur, hauteur = img.size # met les valeurs de largeur et de hauteur pour ce nouvel objet

for x in range(0,    314       ): # à modifier
    for y in range(0,   314              ): # à modifier
        # Ici on traite le pixel (x,y) de l'image
        ( r , v , b )=img.getpixel((x,y))
        new_r =   125      # à modifier pour obtenir le rouge plus intense 
        new_v =    125       # à modifier pour obtenir le vert plus intense
        new_b =    125       # à modifier pour obtenir le bleu moins intense
        img.putpixel((x,y), ( new_r, new_v , new_b )) # à compléter

img # pour afficher l'image après traitement

# %% [markdown]
# # 4. Réalisation d'un filtre gris (niveau intermédiaire)
#
# On propose ensuite de passer une image couleurs en niveaux de gris :
#
# pour cela, il faut comprendre ce que signifie le gris en mode RVB :
#
# On passe du noir (0,0,0) au blanc (255,255,255) avec les valeurs intermédiaire de gris qui ont **toutes la même valeur pour (r,v,b)**.
#
#
# Se pose alors la question de savoir quelle valeur (L,L,L) mettre pour un gris donnée par (r,v,b) ?
#
# On peut essayer de faire la moyenne des trois valeurs : $L_{moyenne} = \frac{(r+v+b)}{3}$

# %% [markdown]
# <div class="alert alert-warning" role="alert">
#     <strong> Travail à faire  : </strong> <br>
#     --> sur la fiche réponse : compléter le tableau pour L moyenné<br>
#     --> Quel problème se pose ?<br>
# </div>

# %% [markdown]
# Pour éviter les confusions de couleurs, on utilise une moyenne pondérée.
# Les pondérations dépendent notamment de la sensibilité des couleurs primaires à l’œil humain. <br>
# La formule couramment utilisée est :   $ L_{pondere} = \frac{(21 * r + 71*v + 8*b)}{100} $
#
# Dans cette formule, on voit que l'oeil humain est particulièrement sensible au vert et donc on lui attribue un coefficient plus important.
#
# Sous Python, on écrira `L = (21*r + 71*v + 8*b)//100` <br>
# Le // désigne l'opérateur division entière qui renvoie un nombre entier .

# %% [markdown]
# <div class="alert alert-warning" role="alert">
#     <strong> Travail à faire  : </strong> <br>
#     --> sur la fiche réponse : compléter le tableau pour L pondéré et vérifier l'utilité de ce calcul<br>
#     --> sur le notebook : modifier le code proposé ci-dessous
# </div>

# %%
img=open("colors.jpg") #recrée un objet img qui contient l'image colors.jpg si celui-ci a été modifié avant
largeur, hauteur = img.size # met les valeurs de largeur et de hauteur pour ce nouvel objet

for x in range(0, 314 ): # à modifier pour traiter toute l'image
    for y in range(0, 314 ): # à modifier pour traiter toute l'image
        # Ici on traite le pixel (x,y) de l'image
        (r,v,b)=img.getpixel((x,y))
        L = (r + v + b)//3 # à modifier pour avoir le bon calcul de L
        img.putpixel((x,y), (L,0,0))
img # pour afficher l'image dans le notebook

# %% [markdown]
# <div class="alert alert-success" role="alert">
#  <strong> Le travail est terminé !</strong> <br>
# </div>
